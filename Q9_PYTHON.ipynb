# %%
####Question 9
import pandas as pd

# %%
### Reading the file using read_csv()
data=pd.read_csv('https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD')

# %%
data.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make  \
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL X          Battery Electric Vehicle (BEV)
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# ...

# %%
● Get all the cars and their types that do not qualify for clean alternative fuel vehicle

# %%
### VIN is "Vehicle Identification Number"-->No two cars will have same VIN

# %%
### Grouping the categories in the 'Clean Alternative Fuel Vehicle (CAFV) Eligibility' column
data.groupby('Clean Alternative Fuel Vehicle (CAFV) Eligibility')['VIN (1-10)'].count()
# Out:
# Clean Alternative Fuel Vehicle (CAFV) Eligibility
# Clean Alternative Fuel Vehicle Eligible                         60551
# Eligibility unknown as battery range has not been researched    53446
# Not eligible due to low battery range                           16446
# Name: VIN (1-10), dtype: int64

# %%
###Filtering the columns as per our problem statement
a=data[data['Clean Alternative Fuel Vehicle (CAFV) Eligibility']=='Not eligible due to low battery range']
b=a[['VIN (1-10)','Make','Model','Electric Vehicle Type']]

# %%
b
# Out:
#         VIN (1-10)    Make        Model  \
# 6       3FA6P0PU1G    FORD       FUSION
# 7       WA1F2AFY8P    AUDI         Q5 E
# 8       1FADP5CU0E    FORD        C-MAX
# 14      1FADP5FU4H    FORD        C-MAX
# 15      KNDCM3LD8L     KIA         NIRO
# ...            ...     ...          ...
# 130377  WBAJA9C55K     BMW         530E
# 130385  WAUUPBFF2G    AUDI           A3
# 130390  1C4JJXR65P    JEEP     WRANGLER
# 130407  JTDKARFP1H  TOYOTA  PRIUS PRIME
# 130437  WBA13AG06M     BMW         530E
#
#                          Electric Vehicle Type
# 6       Plug-in Hybrid Electric Vehicle (PHEV)
# 7       Plug-in Hybrid Electric Vehicle (PHEV)
# 8       Plug-in Hybrid Electric Vehicle (PHEV)
# 14      Plug-in Hybrid Electric Vehicle (PHEV)
# 15      Plug-in Hybrid Electric Vehicle (PHEV)
# ...                                        ...
# 130377  Plug-in Hybrid Electric Vehicle (PHEV)
# 130385  Plug-in Hybrid Electric Vehicle (PHEV)
# 130390  Plug-in Hybrid Electric Vehicle (PHEV)
# ...

# %% [markdown]
# #### There are total of 16446 vehicles which do not qualify for 'Clean Alternative Fuel Vehicle'

# %% [raw]
# ● Get all TESLA cars with the model year, and model type made in Bothell City.

# %%
x=data[data['City']=='Bothell'] ###Filtering the data for the cars made in 'Bothell' city

# %%
y=x[x['Make']=='TESLA'] ###Filtering the Tesla cars from cars made in 'Bothell' city

# %%
y[['VIN (1-10)','Model Year','Model','Electric Vehicle Type']] ### Filtering the data as per the requirement in our problem state,emt
# Out:
#         VIN (1-10)  Model Year    Model           Electric Vehicle Type
# 39      5YJ3E1EA6L        2020  MODEL 3  Battery Electric Vehicle (BEV)
# 217     5YJ3E1EB9N        2022  MODEL 3  Battery Electric Vehicle (BEV)
# 218     7SAYGDEEXN        2022  MODEL Y  Battery Electric Vehicle (BEV)
# 222     5YJ3E1EB6J        2018  MODEL 3  Battery Electric Vehicle (BEV)
# 292     5YJXCBE40H        2017  MODEL X  Battery Electric Vehicle (BEV)
# ...            ...         ...      ...                             ...
# 129778  5YJ3E1EB3K        2019  MODEL 3  Battery Electric Vehicle (BEV)
# 129954  5YJ3E1EB3M        2021  MODEL 3  Battery Electric Vehicle (BEV)
# 129976  5YJSA1S10E        2014  MODEL S  Battery Electric Vehicle (BEV)
# 130295  5YJ3E1EA8N        2022  MODEL 3  Battery Electric Vehicle (BEV)
# 130392  5YJ3E1EA9J        2018  MODEL 3  Battery Electric Vehicle (BEV)
#
# [2407 rows x 4 columns]

# %% [markdown]
# #### It is clear that there are 2407 number of Tesla cars made in Bothell City

# %%
● Get all the cars that have an electric range of more than 100, and were made after
2015

# %%
p=data[data['Electric Range']>100] ### Filtering the data for cars having 'Electric Range' greater than 100

# %%
q=p[p['Model Year']>2015] ### Filtering the cars which are made after 2015

# %%
q
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# 12      5YJ3E1EC7L  Thurston          Lacey    WA      98503.0        2020
# 13      5YJ3E1EB2L  Thurston        Olympia    WA      98516.0        2020
# ...            ...       ...            ...   ...          ...         ...
# 130417  5YJYGDEE5L    Pierce         Tacoma    WA      98444.0        2020
# 130428  1N4AZ1CP0J   Clallam         Sequim    WA      98382.0        2018
# 130432  5YJYGDEEXL      King         Vashon    WA      98070.0        2020
# 130436  5YJ3E1EB0J   Whatcom         Blaine    WA      98230.0        2018
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
#
#           Make    Model           Electric Vehicle Type  \
# ...

# %%
● Draw plots to show the distribution between city and electric vehicle type

# %%
data.groupby('Electric Vehicle Type')['City'].count().plot.bar()
# Out:
# <AxesSubplot: xlabel='Electric Vehicle Type'>

# %% [markdown]
# #### It is clear that the number of 'BEV's in cities is higher than the 'PHEV' in cities

# %%
# Pie Chart
plt.figure(figsize=(10, 6))
data['Electric Vehicle Type'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of Electric Vehicle Types')
plt.show()
